# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
import pandas as pd
import numpy as np
from modules import transfer_entropy as TE

# %%
lista = ["Atlanta-Sandy Springs-Alpharetta, GA MSA",
    "Baltimore-Columbia-Towson, MD MSA",
    "Boston-Cambridge-Newton, MA-NH MSA",
    "Chicago-Naperville-Elgin, IL-IN-WI MSA",
    "Dallas-Fort Worth-Arlington, TX MSA",
    "Denver-Aurora-Lakewood, CO MSA",
    "Detroit_Dearborn, MI MSA",
    "Houston-The Woodlands-Sugar Land, TX MSA",
    "Los Angeles-Long Beach-Anaheim, CA MSA",
    "Miami-Fort Lauderdale-West Palm Beach, FL MSA",
    "Minneapolis-St. Paul-Bloomington, MN-WI MSA",
    "New York-Newark-Jersey City, NY-NJ-PA MSA",
    "Philadelphia-Camden-Wilmington, PA-NJ-DE-MD MSA",
    "Phoenix-Mesa-Chandler, AZ MSA",
    "Riverside-San Bernardino-Ontario, CA MSA",
    "San Francisco-Oakland-Berkeley, CA MSA",
    "Tampa-St. Petersburg-Clearwater, FL MSA",
    "Washington-Arlington-Alexandria, DC-VA-MD-WV MSA"]
df = pd.read_csv("data/Times_series_sa_det.csv")

# %% [markdown]
# The p-values given in the paper were computed with iterations = 20,000

# %%
for arg in lista:
    Positive_Tweets = TE.Median_Symbolise_3bins(df["Tweet search - "+arg+"_sent_Hugged_Positive_sa_det"])
    Negative_Tweets = TE.Median_Symbolise_3bins(df["Tweet search - "+arg+"_sent_Hugged_Negative_sa_det"])
    crimes =          TE.Median_Symbolise_3bins(df[arg+"_crimes_lagged_sa_det"])
    Police_brutality =TE.Median_Symbolise_3bins(df["Police_Brutality_lagged_sa_det"])
    results = TE.ComputeH1H2_lags(PB = Police_brutality,CR = crimes,
                             PT = Positive_Tweets,NT = Negative_Tweets,iterations = 3)    
    print(arg)
    display(results)
# Out:
# Atlanta-Sandy Springs-Alpharetta, GA MSA
#         Source           Target        TE  Quantile  p_val  \
# 0       Crimes  negative Tweets  0.006750  0.006738   0.25
# 1       Crimes  negative Tweets  0.025828  0.029404   0.75
# 2       Crimes  negative Tweets  0.021633  0.029204   0.50
# 3       Crimes  Positive Tweets  0.007230  0.007428   0.50
# 4       Crimes  Positive Tweets  0.021408  0.030585   0.75
# 5       Crimes  Positive Tweets  0.024375  0.022605   0.00
# 6  Police brut  Negative Tweets  0.030613  0.010089   0.00
# 7  Police brut  Negative Tweets  0.055498  0.031747   0.00
# 8  Police brut  Negative Tweets  0.044546  0.027481   0.00
#
#                          lags
# 0  target1 source1 condition1
# 1  target1 source2 condition1
# 2  target1 source1 condition2
# 3  target1 source1 condition1
# 4  target1 source2 condition1
# 5  target1 source1 condition2
# 6  target1 source1 condition1
# 7  target1 source2 condition1
# 8  target1 source1 condition2
# Baltimore-Columbia-Towson, MD MSA
#         Source           Target        TE  Quantile  p_val  \
# 0       Crimes  negative Tweets  0.005385  0.006961   0.75
# 1       Crimes  negative Tweets  0.023388  0.032838   0.75
# 2       Crimes  negative Tweets  0.019906  0.021499   0.25
# 3       Crimes  Positive Tweets  0.010477  0.008442   0.00
# 4       Crimes  Positive Tweets  0.031631  0.033565   0.25
# 5       Crimes  Positive Tweets  0.027289  0.021704   0.00
# 6  Police brut  Negative Tweets  0.018878  0.008634   0.00
# 7  Police brut  Negative Tweets  0.044602  0.033161   0.00
# 8  Police brut  Negative Tweets  0.030329  0.022878   0.00
#
#                          lags
# 0  target1 source1 condition1
# 1  target1 source2 condition1
# 2  target1 source1 condition2
# 3  target1 source1 condition1
# 4  target1 source2 condition1
# 5  target1 source1 condition2
# 6  target1 source1 condition1
# 7  target1 source2 condition1
# 8  target1 source1 condition2
# Boston-Cambridge-Newton, MA-NH MSA
#         Source           Target        TE  Quantile  p_val  \
# 0       Crimes  negative Tweets  0
0.00
#
#                          lags
# 0  target1 source1 condition1
# 1  target1 source2 condition1
# 2  target1 source1 condition2
# 3  target1 source1 condition1
# 4  target1 source2 condition1
# 5  target1 source1 condition2
# 6  target1 source1 condition1
# 7  target1 source2 condition1
# 8  target1 source1 condition2
# Los Angeles-Long Beach-Anaheim, CA MSA
#         Source           Target        TE  Quantile  p_val  \
# 0       Crimes  negative Tweets  0.008174  0.009724   0.25
# 1       Crimes  negative Tweets  0.035147  0.030326   0.00
# 2       Crimes  negative Tweets  0.018928  0.026731   0.75
# 3       Crimes  Positive Tweets  0.006367  0.008287   0.50
# 4       Crimes  Positive Tweets  0.036769  0.030973   0.00
# 5       Crimes  Positive Tweets  0.026468  0.021392   0.00
# 6  Police brut  Negative Tweets  0.032622  0.006317   0.00
# 7  Police brut  Negative Tweets  0.053932  0.029484   0.00
# 8  Police brut  Negative Tweets  0.050824  0.023985   0.00
#
#                          lags
# 0  target1 source1 condition1
# 1  target1 source2 condition1
# 2  target1 source1 condition2
# 3  target1 source1 condition1
# 4  target1 source2 condition1
# 5  target1 source1 condition2
# 6  target1 source1 condition1
# 7  target1 source2 condition1
# 8  target1 source1 condition2
# Miami-Fort Lauderdale-West Palm Beach, FL MSA
#         Source           Target        TE  Quantile  p_val  \
# 0       Crimes  negative Tweets  0.006204  0.008670   0.75
# 1       Crimes  negative Tweets  0.028312  0.029419   0.50
# 2       Crimes  negative Tweets  0.019133  0.024071   0.50
# 3       Crimes  Positive Tweets  0.007154  0.007423   0.25
# 4       Crimes  Positive Tweets  0.027824  0.034482   0.50
# 5       Crimes  Positive Tweets  0.016177  0.025485   0.75
# 6  Police brut  Negative Tweets  0.034386  0.007200   0.00
# 7  Police brut  Negative Tweets  0.055743  0.032202   0.00
# 8  Police brut  Negative Tweets  0.049718  0.023471   0.00
#
#                          lags
# 0  target1 source1 condition1
# 1  target1 source2 condition1
# 2  target1 source1 condition2
# 3  target1 source1 condition1
# 4  target1 source2 condition1
# 5  target1 source1 condition2
# 6  target1 source1 condition1
# 7  target1 source2 condition1
# 8  target1 source1 condition2
# Minneapolis-St. Paul-Bloomington, MN-WI MSA
#         Source           Target        TE  Quantile  p_val  \
# 0       Crimes  negative Tweets  0.006294  0.008836   0.50
# 1       Crimes  negative Tweets  0.027124  0.028445   0.25
# 2       Crimes  negative Tweets  0.019679  0.025330   0.75
# 3       Crimes  Positive Tweets  0.007199  0.008879   0.25
# 4       Crimes  Positive Tweets  0.027326  0.031652   0.75
# 5       Crimes  Positive Tweets  0.024432  0.024523   0.25
# 6  Police brut  Negative Tweets  0.030484  0.007174   0.00
# 7  Police brut  Negative Tweets  0.056916  0.028420   0.00
# 8  Police brut  Negative Tweets  0.045911  0.023443   0.00
#
#                          lags
# 0  target1 source1 condition1
# 1  target1 source2 condition1
# 2  target1 source1 condition2
# 3  target1 source1 condition1
# 4  target1 source2 condition1
# 5  target1 source1 condition2
# 6  target1 source1 condition1
# 7  target1 source2 condition1
# 8  target1 source1 condition2
# New York-Newark-Jersey City, NY-NJ-PA MSA
#         Source           Target        TE  Quantile  p_val  \
# 0       Crimes  negative Tweets  0.009057  0.009608   0.25
# 1       Crimes  negative Tweets  0.032456  0.029716   0.00
# 2       Crimes  negative Tweets  0.027438  0.024609   0.00
# 3       Crimes  Positive Tweets  0.005416  0.008466   0.75
# 4       Crimes  Positive Tweets  0.029020  0.028448   0.00
# 5       Crimes  Positive Tweets  0.018794  0.021528   0.75
# 6  Police brut  Negative Tweets  0.029132  0.006858   0.00
# 7  Police brut  Negative Tweets  0.059556  0.030345   0.00
# 8  Police brut  Negative Tweets  0.043601  0.024216   0.00
#
#                          lags
# 0  target1 source1 condition1
# 1  target1 source2 condition1
# 2  target1 source1 condition2
# 3  target1 source1 condition1
# 4  target1 source2 condition1
# 5  target1 source1 condition2
# 6  target1 source1 condition1
# 7  target1 source2 condition1
# 8  target1 source1 condition2
# Philadelphia-Camden-Wilmington, PA-NJ-DE-MD MSA
#         Source           Target        TE  Quantile  p_val  \
# 0       Crimes  negative Tweets  0.005607  0.005651   0.25
# 1       Crimes  negative Tweets  0.024935  0.029821   0.75
# 2       Crimes  negative Tweets  0.019328  0.024512   0.75
# 3       Crimes  Positive Tweets  0.006588  0.006476   0.00
# 4       Crimes  Positive Tweets  0.032013  0.032657   0.25
# 5       Crimes  Positive Tweets  0.018545  0.024311   0.50
# 6  Police brut  Negative Tweets  0.028192  0.010645   0.00
# 7  Police brut  Negative Tweets  0.053650  0.030457   0.00
# 8  Police brut  Negative Tweets  0.042562  0.025552   0.00
#
#                          lags
# 0  target1 source1 condition1
# 1  target1 source2 condition1
# 2  target1 source1 condition2
# 3  target1 source1 condition1
# 4  target1 source2 condition1
# 5  target1 source1 condition2
# 6  target1 source1 condition1
# 7  target1 source2 condition1
# 8  target1 source1 condition2
# Phoenix-Mesa-Chandler, AZ MSA
#         Source           Target        TE  Quantile  p_val  \
# 0       Crimes  negative Tweets  0.006425  0.006926   0.25
# 1       Crimes  negative Tweets  0.020057  0.028991   0.75
# 2       Crimes  negative Tweets  0.019890  0.021930   0.75
# 3       Crimes  Positive Tweets  0.007327  0.006382   0.00
# 4       Crimes  Positive Tweets  0.029989  0.028102   0.00
# 5       Crimes  Positive Tweets  0.020174  0.021319   0.50
# 6  Police brut  Negative Tweets  0.038828  0.009205   0.00
# 7  Police brut  Negative Tweets  0.067368  0.028664   0.00
# 8  Police brut  Negative Tweets  0.046689  0.027140   0.00
#
#                          lags
# 0  target1 source1 condition1
# 1  target1 source2 condition1
# 2  target1 source1 condition2
# 3  target1 source1 condition1
# 4  target1 source2 condition1
# 5  target1 source1 condition2
# 6  target1 source1 condition1
# 7  target1 source2 condition1
# 8  target1 source1 condition2
# Riverside-San Bernardino-Ontario, CA MSA
#         Source           Target        TE  Quantile  p_val  \
# 0       Crimes  negative Tweets  0.007652  0.009296   0.25
# 1       Crimes  negative Tweets  0.030392  0.035065   0.25
# 2       Crimes  negative Tweets  0.019058  0.023593   0.75
# 3       Crimes  Positive Tweets  0.006716  0.005932   0.00
# 4       Crimes  Positive Tweets  0.027442  0.031782   0.75
# 5       Crimes  Positive Tweets  0.020086  0.028042   0.50
# 6  Police brut  Negative Tweets  0.021698  0.009854   0.00
# 7  Police brut  Negative Tweets  0.047205  0.026098   0.00
# 8  Police brut  Negative Tweets  0.035945  0.022495   0.00
#
#                          lags
# 0  target1 source1 condition1
# 1  target1 source2 condition1
# 2  target1 source1 condition2
# 3  target1 source1 condition1
# 4  target1 source2 condition1
# 5  target1 source1 condition2
# 6  target1 source1 condition1
# 7  target1 source2 condition1
# 8  target1 source1 condition2
# San Francisco-Oakland-Berkeley, CA MSA
#         Source           Target        TE  Quantile  p_val  \
# 0       Crimes  negative Tweets  0.006600  0.007520   0.50
# 1       Crimes  negative Tweets  0.031220  0.027776   0.00
# 2       Crimes  negative Tweets  0.018072  0.022127   0.50
# 3       Crimes  Positive Tweets  0.005334  0.007192   0.50
# 4       Crimes  Positive Tweets  0.023021  0.029793   0.75
# 5       Crimes  Positive Tweets  0.019779  0.022621   0.75
# 6  Police brut  Negative Tweets  0.029348  0.007245   0.00
# 7  Police brut  Negative Tweets  0.054521  0.035512   0.00
# 8  Police brut  Negative Tweets  0.044437  0.027034   0.00
#
#                          lags
# 0  target1 source1 condition1
# 1  target1 source2 condition1
# 2  target1 source1 condition2
# 3  target1 source1 condition1
# 4  target1 source2 condition1
# 5  target1 source1 condition2
# 6  target1 source1 condition1
# 7  target1 source2 condition1
# 8  target1 source1 condition2
# Tampa-St. Petersburg-Clearwater, FL MSA
#         Source           Target        TE  Quantile  p_val  \
# 0       Crimes  negative Tweets  0.009636  0.007085   0.00
# 1       Crimes  negative Tweets  0.027702  0.029656   0.75
# 2       Crimes  negative Tweets  0.025026  0.026733   0.50
# 3       Crimes  Positive Tweets  0.007304  0.007095   0.00
# 4       Crimes  Positive Tweets  0.031857  0.027610   0.00
# 5       Crimes  Positive Tweets  0.016487  0.023321   0.75
# 6  Police brut  Negative Tweets  0.039133  0.012461   0.00
# 7  Police brut  Negative Tweets  0.071769  0.036415   0.00
# 8  Police brut  Negative Tweets  0.049719  0.022501   0.00
#
#                          lags
# 0  target1 source1 condition1
# 1  target1 source2 condition1
# 2  target1 source1 condition2
# 3  target1 source1 condition1
# 4  target1 source2 condition1
# 5  target1 source1 condition2
# 6  target1 source1 condition1
# 7  target1 source2 condition1
# 8  target1 source1 condition2
# Washington-Arlington-Alexandria, DC-VA-MD-WV MSA
#         Source           Target        TE  Quantile  p_val  \
# 0       Crimes  negative Tweets  0.011115  0.007501   0.00
# 1       Crimes  negative Tweets  0.032919  0.029986   0.00
# 2       Crimes  negative Tweets  0.024245  0.024648   0.25
# 3       Crimes  Positive Tweets  0.009674  0.008625   0.00
# 4       Crimes  Positive Tweets  0.030039  0.026778   0.00
# 5       Crimes  Positive Tweets  0.024338  0.023752   0.00
# 6  Police brut  Negative Tweets  0.038230  0.007152   0.00
# 7  Police brut  Negative Tweets  0.060509  0.031026   0.00
# 8  Police brut  Negative Tweets  0.054930  0.024122   0.00
#
#                          lags
# 0  target1 source1 condition1
# 1  target1 source2 condition1
# 2  target1 source1 condition2
# 3  target1 source1 condition1
# 4  target1 source2 condition1
# 5  target1 source1 condition2
# 6  target1 source1 condition1
# 7  target1 source2 condition1
# 8  target1 source1 condition2

# %%
print("Pandas version:",pd.__version__)
print("Numpy version:",np.__version__)
# Out:
# Pandas version: 1.4.2
# Numpy version: 1.21.6
